# %% [markdown]
# 𝗘𝗫𝗣𝗟𝗢𝗥𝗔𝗧𝗢𝗥𝗬 𝗗𝗔𝗧𝗔 𝗔𝗡𝗔𝗟𝗬𝗦𝗜𝗦 - 𝗧𝗘𝗥𝗥𝗢𝗥𝗜𝗦𝗠
#
# 𝐃𝐀𝐓𝐀𝐒𝐄𝐓: 𝗚𝗹𝗼𝗯𝗮𝗹𝗧𝗲𝗿𝗿𝗼𝗿𝗶𝘀𝗺𝗗𝗮𝘁𝗮𝘀𝗲𝘁(𝗵𝘁𝘁𝗽𝘀://𝗯𝗶𝘁.𝗹𝘆/𝟮𝗧𝗞𝟱𝗫𝗻𝟱)

# %% [markdown]
#           𝗜𝗠𝗣𝗢𝗥𝗧𝗜𝗡𝗚 𝗔𝗟𝗟 𝗧𝗛𝗘 𝗟𝗜𝗕𝗥𝗔𝗥𝗜𝗘𝗦 𝗥𝗘𝗤𝗨𝗜𝗥𝗘𝗗 𝗙𝗢𝗥 𝗔𝗡𝗔𝗟𝗬𝗦𝗜𝗦

# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
print("Imported Sucessfully.")
# Out:
# Imported Sucessfully.

# %% [markdown]
#           𝗗𝗔𝗧𝗔 𝗘𝗫𝗣𝗟𝗢𝗥𝗔𝗧𝗜𝗢𝗡 𝗔𝗡𝗗 𝗔𝗡𝗔𝗟𝗬𝗦𝗜𝗦 - 𝗟𝗢𝗔𝗗𝗜𝗡𝗚 𝗔𝗡𝗗 𝗢𝗕𝗦𝗘𝗥𝗩𝗜𝗡𝗚 𝗧𝗛𝗘 𝗗𝗔𝗧𝗔

# %%
data=pd.read_csv("C:/Users/HP/Downloads/Global_Terrorism.csv", encoding="latin1")
print("Global Terrorism Data Loaded Successfully.")
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_10620\3202467971.py:1: DtypeWarning: Columns (4,6,31,33,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types. Specify dtype option on import or set low_memory=False.
#   data=pd.read_csv("C:/Users/HP/Downloads/Global_Terrorism.csv", encoding="latin1")
# Global Terrorism Data Loaded Successfully.

# %%
data.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
# ...

# %%
data.tail()
# Out:
#              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 181686  201712310022   2017      12    31        NaN         0        NaN
# 181687  201712310029   2017      12    31        NaN         0        NaN
# 181688  201712310030   2017      12    31        NaN         0        NaN
# 181689  201712310031   2017      12    31        NaN         0        NaN
# 181690  201712310032   2017      12    31        NaN         0        NaN
#
#         country  country_txt  region  ... addnotes  \
# 181686      182      Somalia      11  ...      NaN
# 181687      200        Syria      10  ...      NaN
# 181688      160  Philippines       5  ...      NaN
# 181689       92        India       6  ...      NaN
# 181690      160  Philippines       5  ...      NaN
#
#                                                    scite1  \
# 181686  "Somalia: Al-Shabaab Militants Attack Army Che...
# 181687  "Putin's 'victory' in Syria has turned into a ...
# ...

# %% [markdown]
#           𝗨𝗡𝗗𝗘𝗥𝗦𝗧𝗔𝗡𝗗𝗜𝗡𝗚 𝗧𝗛𝗘 𝗗𝗔𝗧𝗔

# %%
#DESCRIBE THE SHAPE - NUMBER OF ROWS AND COLUMNS
data.shape
# Out:
# (181691, 135)

# %%
#INFORMATION REGARDING THE DATASETS
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Columns: 135 entries, eventid to related
# dtypes: float64(55), int64(22), object(58)
# memory usage: 187.1+ MB

# %%
#DESCRIBING ALL THE COLUMNS PRESENT IN THE DATA
data.columns.values
# Out:
# array(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region', 'region_txt',
#        'provstate', 'city', 'latitude', 'longitude', 'specificity',
#        'vicinity', 'location', 'summary', 'crit1', 'crit2', 'crit3',
#        'doubtterr', 'alternative', 'alternative_txt', 'multiple',
#        'success', 'suicide', 'attacktype1', 'attacktype1_txt',
#        'attacktype2', 'attacktype2_txt', 'attacktype3', 'attacktype3_txt',
#        'targtype1', 'targtype1_txt', 'targsubtype1', 'targsubtype1_txt',
#        'corp1', 'target1', 'natlty1', 'natlty1_txt', 'targtype2',
#        'targtype2_txt', 'targsubtype2', 'targsubtype2_txt', 'corp2',
#        'target2', 'natlty2', 'natlty2_txt', 'targtype3', 'targtype3_txt',
#        'targsubtype3', 'targsubtype3_txt', 'corp3', 'target3', 'natlty3',
#        'natlty3_txt', 'gname', 'gsubname', 'gname2', 'gsubname2',
# ...

# %%
#PRESENTING THE DATA IN MORE DETAILED WAY
for i in data.columns:
    print(i, end=", ")
# Out:
# eventid, iyear, imonth, iday, approxdate, extended, resolution, country, country_txt, region, region_txt, provstate, city, latitude, longitude, specificity, vicinity, location, summary, crit1, crit2, crit3, doubtterr, alternative, alternative_txt, multiple, success, suicide, attacktype1, attacktype1_txt, attacktype2, attacktype2_txt, attacktype3, attacktype3_txt, targtype1, targtype1_txt, targsubtype1, targsubtype1_txt, corp1, target1, natlty1, natlty1_txt, targtype2, targtype2_txt, targsubtype2, targsubtype2_txt, corp2, target2, natlty2, natlty2_txt, targtype3, targtype3_txt, targsubtype3, targsubtype3_txt, corp3, target3, natlty3, natlty3_txt, gname, gsubname, gname2, gsubname2, gname3, gsubname3, motive, guncertain1, guncertain2, guncertain3, individual, nperps, nperpcap, claimed, claimmode, claimmode_txt, claim2, claimmode2, claimmode2_txt, claim3, claimmode3, claimmode3_txt, compclaim, weaptype1, weaptype1_txt, weapsubtype1, weapsubtype1_txt, weaptype2, weaptype2_txt, weapsubtyp
# ...

# %% [markdown]
#           𝗖𝗟𝗘𝗔𝗡𝗜𝗡𝗚 𝗧𝗛𝗘 𝗗𝗔𝗧𝗔

# %%
#REQUIRED COLUMNS FOR THIS TASK
data=data[["iyear","imonth","iday","country_txt","region_txt","provstate","city",
       "latitude","longitude","location","summary","attacktype1_txt","targtype1_txt",
       "gname","motive","weaptype1_txt","nkill","nwound","addnotes"]]
data.head()
# Out:
#    iyear  imonth  iday         country_txt                   region_txt  \
# 0   1970       7     2  Dominican Republic  Central America & Caribbean
# 1   1970       0     0              Mexico                North America
# 2   1970       1     0         Philippines               Southeast Asia
# 3   1970       1     0              Greece               Western Europe
# 4   1970       1     0               Japan                    East Asia
#
#   provstate           city   latitude   longitude location summary  \
# 0       NaN  Santo Domingo  18.456792  -69.951164      NaN     NaN
# 1   Federal    Mexico city  19.371887  -99.086624      NaN     NaN
# 2    Tarlac        Unknown  15.478598  120.599741      NaN     NaN
# 3    Attica         Athens  37.997490   23.762728      NaN     NaN
# 4   Fukouka        Fukouka  33.580412  130.396361      NaN     NaN
#
#                   attacktype1_txt                targtype1_txt  \
# ...

# %%
#RENAMING THE DATSETS
data.rename(columns={"iyear":"Year","imonth":"Month","iday":"Day","country_txt":"Country",
                   "region_txt":"Region","provstate":"Province/State","city":"City",
                   "latitude":"Latitude","longitude":"Longitude","location":"Location",
                   "summary":"Summary","attacktype1_txt":"Attack Type","targtype1_txt":"Target Type",
                   "gname":"Group Name","motive":"Motive","weaptype1_txt":"Weapon Type",
                   "nkill":"Killed","nwound":"Wounded","addnotes":"Add Notes"},inplace=True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_10620\3313006980.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.rename(columns={"iyear":"Year","imonth":"Month","iday":"Day","country_txt":"Country",

# %%
#EXTRACTING THE DATA AFTER RENAMING
data = data[['Year','Month','Day','Country','Region','Province/State','City','Latitude','Longitude','Location','Summary',
             'Attack Type','Target Type','Group Name','Motive','Weapon Type','Killed','Wounded','Add Notes']]
data.head()
# Out:
#    Year  Month  Day             Country                       Region  \
# 0  1970      7    2  Dominican Republic  Central America & Caribbean
# 1  1970      0    0              Mexico                North America
# 2  1970      1    0         Philippines               Southeast Asia
# 3  1970      1    0              Greece               Western Europe
# 4  1970      1    0               Japan                    East Asia
#
#   Province/State           City   Latitude   Longitude Location Summary  \
# 0            NaN  Santo Domingo  18.456792  -69.951164      NaN     NaN
# 1        Federal    Mexico city  19.371887  -99.086624      NaN     NaN
# 2         Tarlac        Unknown  15.478598  120.599741      NaN     NaN
# 3         Attica         Athens  37.997490   23.762728      NaN     NaN
# 4        Fukouka        Fukouka  33.580412  130.396361      NaN     NaN
#
#                       Attack Type                  Target Type  \
# ...

# %% [markdown]
#           𝗣𝗥𝗘𝗣𝗔𝗥𝗜𝗡𝗚 𝗧𝗛𝗘 𝗗𝗔𝗧𝗔𝗦𝗘𝗧𝗦

# %%
#DESCRIBE THE SHAPE - NUMBER OF ROWS AND COLUMNS
data.shape
# Out:
# (181691, 19)

# %%
#INFORMATION REGARDING THE DATASETS
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Data columns (total 19 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Year            181691 non-null  int64
#  1   Month           181691 non-null  int64
#  2   Day             181691 non-null  int64
#  3   Country         181691 non-null  object
#  4   Region          181691 non-null  object
#  5   Province/State  181270 non-null  object
#  6   City            181257 non-null  object
#  7   Latitude        177135 non-null  float64
#  8   Longitude       177134 non-null  float64
#  9   Location        55495 non-null   object
#  10  Summary         115562 non-null  object
#  11  Attack Type     181691 non-null  object
#  12  Target Type     181691 non-null  object
#  13  Group Name      181691 non-null  object
#  14  Motive          50561 non-null   object
#  15  Weapon Type     181691 non-null  object
# ...

# %%
#CHECKING FOR NULL VALUES
data.isnull().sum()
# Out:
# Year                   0
# Month                  0
# Day                    0
# Country                0
# Region                 0
# Province/State       421
# City                 434
# Latitude            4556
# Longitude           4557
# Location          126196
# Summary            66129
# Attack Type            0
# Target Type            0
# Group Name             0
# Motive            131130
# Weapon Type            0
# Killed             10313
# Wounded            16311
# Add Notes         153402
# dtype: int64

# %%
#FILLING THE NULL ENTERIES COLUMNS WITH ZERO
data["Killed"] = data["Killed"].fillna(0)
data["Wounded"] = data["Wounded"].fillna(0)

#CREATING BY ADDING KILLED AND WOUNDED ONCES
data["Casualty"] = data["Killed"] + data["Wounded"]

# %%
#DISPLAY THE SUMMARY
data.describe()
# Out:
#                 Year          Month            Day       Latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean     2002.638997       6.467277      15.505644      23.498343
# std        13.259430       3.388303       8.814045      18.569242
# min      1970.000000       0.000000       0.000000     -53.154613
# 25%      1991.000000       4.000000       8.000000      11.510046
# 50%      2009.000000       6.000000      15.000000      31.467463
# 75%      2014.000000       9.000000      23.000000      34.685087
# max      2017.000000      12.000000      31.000000      74.633553
#
#           Longitude         Killed        Wounded       Casualty
# count  1.771340e+05  181691.000000  181691.000000  181691.000000
# mean  -4.586957e+02       2.266860       2.883296       5.150156
# std    2.047790e+05      11.227057      34.309747      40.555416
# min   -8.618590e+07       0.000000       0.000000       0.000000
# ...

# %% [markdown]
#           𝗙𝗥𝗢𝗠 𝗧𝗛𝗘 𝗔𝗕𝗢𝗩𝗘 𝗢𝗕𝗦𝗘𝗥𝗩𝗔𝗧𝗜𝗢𝗡 𝗪𝗘 𝗖𝗔𝗡 𝗦𝗔𝗬 𝗧𝗛𝗔𝗧:
#
#     𝟭. 𝗧𝗛𝗘 𝗗𝗔𝗧𝗔 𝗖𝗢𝗡𝗦𝗜𝗦𝗧𝗦 𝗢𝗙 𝗧𝗘𝗥𝗥𝗢𝗥𝗜𝗦𝗧 𝗔𝗖𝗧𝗜𝗩𝗜𝗧𝗜𝗘𝗦 𝗥𝗔𝗡𝗚𝗜𝗡𝗚 𝗙𝗥𝗢𝗠 𝗧𝗛𝗘 𝗬𝗘𝗔𝗥 : 𝟭𝟵𝟳𝟬 - 𝟮𝟬𝟭𝟳
#     𝟮. 𝗠𝗔𝗫𝗜𝗠𝗨𝗠 𝗡𝗨𝗠𝗕𝗘𝗥 𝗢𝗙 𝗣𝗘𝗢𝗣𝗟𝗘 𝗞𝗜𝗟𝗟𝗘𝗗 𝗜𝗡 𝗔𝗡 𝗘𝗩𝗘𝗡𝗧 𝗪𝗘𝗥𝗘 : 𝟭𝟱𝟳𝟬
#     𝟯. 𝗠𝗔𝗫𝗜𝗠𝗨𝗠 𝗡𝗨𝗠𝗕𝗘𝗥 𝗢𝗙 𝗣𝗘𝗢𝗣𝗟𝗘 𝗪𝗢𝗨𝗡𝗗𝗘𝗗 𝗜𝗡 𝗔𝗡 𝗘𝗩𝗘𝗡𝗧 𝗪𝗘𝗥𝗘 : 𝟴𝟭𝟵𝟭
#     𝟰. 𝗠𝗔𝗫𝗜𝗠𝗨𝗠 𝗡𝗨𝗠𝗕𝗘𝗥 𝗢𝗙 𝗧𝗢𝗧𝗔𝗟 𝗖𝗔𝗦𝗨𝗔𝗟𝗧𝗜𝗘𝗦 𝗜𝗡 𝗔𝗡 𝗘𝗩𝗘𝗡𝗧 𝗪𝗘𝗥𝗘 : 𝟵𝟱𝟳𝟰

# %% [markdown]
#           𝗩𝗜𝗦𝗨𝗔𝗟𝗜𝗭𝗜𝗡𝗚 𝗧𝗛𝗘 𝗗𝗔𝗧𝗔 - 𝗣𝗟𝗢𝗧𝗧𝗜𝗡𝗚 𝗙𝗥𝗢𝗠 𝗬𝗘𝗔𝗥 𝟭𝟵𝟳𝟬 - 𝟮𝟬𝟭𝟳

# %% [markdown]
# 𝟭. 𝗬𝗘𝗔𝗥 𝗪𝗜𝗦𝗘 𝗔𝗧𝗧𝗔𝗖𝗞𝗦

# %% [markdown]
#      (𝑨) 𝑵𝑼𝑴𝑩𝑬𝑹 𝑶𝑭 𝑨𝑻𝑻𝑨𝑪𝑲𝑺 𝑰𝑵 𝑬𝑨𝑪𝑯 𝒀𝑬𝑨𝑹

# %%
attacks=data["Year"].value_counts(dropna=False).sort_index().to_frame().reset_index().rename(columns={"index":"Year","Year":"Attacks"}).set_index("Year")
attacks.head()
# Out:
#       Attacks
# Year
# 1970      651
# 1971      471
# 1972      568
# 1973      473
# 1974      581

# %%
attacks.plot(kind="bar",color="CornFlowerBlue",figsize=(13,5),fontsize=9)
plt.title("TIMELINE OF ATTACKS",fontsize=14)
plt.xlabel("YEARS",fontsize=12)
plt.ylabel("NUMBER OF ATTACKS",fontsize=12)
plt.show()

# %% [markdown]
#      (𝑩) 𝑻𝑶𝑻𝑨𝑳 𝑪𝑨𝑺𝑼𝑳𝑨𝑻𝑰𝑬𝑺 (𝑲𝑰𝑳𝑳𝑬𝑫 + 𝑾𝑶𝑼𝑵𝑫𝑬𝑫) 𝑰𝑵 𝑬𝑨𝑪𝑯 𝒀𝑬𝑨𝑹

# %%
yc=data[["Year","Casualty"]].groupby("Year").sum()
yc.head()
# Out:
#       Casualty
# Year
# 1970     386.0
# 1971     255.0
# 1972     975.0
# 1973     865.0
# 1974    1404.0

# %%
yc.plot(kind="bar",color="Orange",figsize=(13,5),fontsize=9)
plt.title("YEAR WISE CASUALTIES",fontsize=14)
plt.xlabel("YEARS",fontsize=12)
plt.xticks(fontsize=12)
plt.ylabel("NUMBER OF CASUALTIES",fontsize=12)
plt.show()

# %% [markdown]
#      (𝑪) 𝑲𝑰𝑳𝑳𝑬𝑫 𝑨𝑵𝑫 𝑾𝑶𝑼𝑵𝑫𝑬𝑫 𝑰𝑵 𝑬𝑨𝑪𝑯 𝒀𝑬𝑨𝑹

# %%
#KILLED IN EACH YEAR
yk=data[["Year","Killed"]].groupby("Year").sum()
yk.head()
# Out:
#       Killed
# Year
# 1970   174.0
# 1971   173.0
# 1972   566.0
# 1973   370.0
# 1974   539.0

# %%
#WOUNDED IN EACH YEAR
yw=data[["Year","Wounded"]].groupby("Year").sum()
yw.head()
# Out:
#       Wounded
# Year
# 1970    212.0
# 1971     82.0
# 1972    409.0
# 1973    495.0
# 1974    865.0

# %%
fig=plt.figure()
ax0=fig.add_subplot(2,1,1)
ax1=fig.add_subplot(2,1,2)

#KILLED
yk.plot(kind="bar",color="Pink",figsize=(15,15), ax=ax0)
ax0.set_title("PEOPLE KILLED IN EACH YEAR",fontsize=14)
ax0.set_xlabel("YEARS",fontsize=12)
ax0.set_ylabel("NUMBER OF PEOPLE KILLED",fontsize=12) 

#WOUNDED
yw.plot(kind="bar",color="LightGreen",figsize=(15,15), ax=ax1)
ax1.set_title("PEOPLE WOUNDED IN EACH YEAR",fontsize=14)
ax1.set_xlabel("YEARS",fontsize=12)
ax1.set_ylabel("NUMBER OF PEOPLE WOUNDED",fontsize=12)

plt.show()

# %% [markdown]
# 𝟮. 𝗥𝗘𝗚𝗜𝗢𝗡 𝗪𝗜𝗦𝗘 𝗔𝗧𝗧𝗔𝗖𝗞𝗦

# %% [markdown]
#      (𝑨) 𝑫𝑰𝑺𝑻𝑹𝑰𝑩𝑼𝑻𝑰𝑶𝑵 𝑶𝑭 𝑻𝑬𝑹𝑹𝑶𝑹𝑰𝑺𝑻 𝑨𝑻𝑻𝑨𝑪𝑲𝑺 𝑶𝑽𝑬𝑹 𝑹𝑬𝑮𝑰𝑶𝑵𝑺

# %%
region=pd.crosstab(data.Year,data.Region)
region.head()
# Out:
# Region  Australasia & Oceania  Central America & Caribbean  Central Asia  \
# Year
# 1970                        1                            7             0
# 1971                        1                            5             0
# 1972                        8                            3             0
# 1973                        1                            6             0
# 1974                        1                           11             0
#
# Region  East Asia  Eastern Europe  Middle East & North Africa  North America  \
# Year
# 1970            2              12                          28            472
# 1971            1               5                          55            247
# 1972            0               1                          53             73
# 1973            2               1                          19             64
# 1974            4               2                          42            111
#
# ...

# %%
region.plot(kind="area", stacked=False, alpha=0.5,figsize=(15,10),fontsize=9)
plt.title("REGION WISE ATTACKS",fontsize=14)
plt.xlabel("YEARS",fontsize=12)
plt.ylabel("NUMBER OF ATACKS",fontsize=12)
plt.show()

# %% [markdown]
#      (𝑩) 𝑻𝑶𝑻𝑨𝑳 𝑻𝑬𝑹𝑹𝑶𝑹𝑰𝑺𝑻 𝑨𝑻𝑻𝑨𝑪𝑲𝑺 𝑰𝑵 𝑬𝑨𝑪𝑯 𝑹𝑬𝑮𝑰𝑶𝑵

# %%
regt=region.transpose()
regt["Total"]=regt.sum(axis=1)
ra=regt["Total"].sort_values(ascending=False)
ra
# Out:
# Region
# Middle East & North Africa     50474
# South Asia                     44974
# South America                  18978
# Sub-Saharan Africa             17550
# Western Europe                 16639
# Southeast Asia                 12485
# Central America & Caribbean    10344
# Eastern Europe                  5144
# North America                   3456
# East Asia                        802
# Central Asia                     563
# Australasia & Oceania            282
# Name: Total, dtype: int64

# %%
ra.plot(kind="bar",color="CornFlowerBlue",figsize=(10,5),fontsize=9)
plt.title("TOTAL TERRORIST ATTACKS IN EACH REGION FROM 1970 - 2017", fontsize=14)
plt.xlabel("REGION", fontsize=12)
plt.ylabel("NUMBER OF ATTACKS", fontsize=12)
plt.show()

# %% [markdown]
#      (𝑪) 𝑻𝑶𝑻𝑨𝑳 𝑪𝑨𝑺𝑼𝑳𝑨𝑻𝑰𝑬𝑺 (𝑲𝑰𝑳𝑳𝑬𝑫 + 𝑾𝑶𝑼𝑵𝑫𝑬𝑫) 𝑰𝑵 𝑬𝑨𝑪𝑯 𝑹𝑬𝑮𝑰𝑶𝑵

# %%
regc=data[["Region","Casualty"]].groupby("Region").sum().sort_values(by="Casualty",ascending=False)
regc
# Out:
#                              Casualty
# Region
# Middle East & North Africa   351950.0
# South Asia                   242679.0
# Sub-Saharan Africa           131243.0
# South America                 45553.0
# Southeast Asia                41896.0
# Central America & Caribbean   37699.0
# North America                 26447.0
# Western Europe                25026.0
# Eastern Europe                19460.0
# East Asia                     10365.0
# Central Asia                   3009.0
# Australasia & Oceania           410.0

# %%
regc.plot(kind="bar",color="Orange",figsize=(13,5),fontsize=9)
plt.title("REGION WISE CASUALTIES",fontsize=14)
plt.xlabel("REGIONS",fontsize=13)
plt.xticks(fontsize=12)
plt.ylabel("NUMBER OF CASUALTIES",fontsize=12)
plt.show()

# %% [markdown]
#      (𝑫) 𝑲𝑰𝑳𝑳𝑬𝑫 𝑨𝑵𝑫 𝑾𝑶𝑼𝑵𝑫𝑬𝑫 𝑰𝑵 𝑬𝑨𝑪𝑯 𝑹𝑬𝑮𝑰𝑶𝑵

# %%
#KILLED IN EACH REGION
regk=data[["Region","Killed"]].groupby("Region").sum().sort_values(by="Killed",ascending=False)
regk
# Out:
#                                Killed
# Region
# Middle East & North Africa   137642.0
# South Asia                   101319.0
# Sub-Saharan Africa            78386.0
# South America                 28849.0
# Central America & Caribbean   28708.0
# Southeast Asia                15637.0
# Eastern Europe                 7415.0
# Western Europe                 6694.0
# North America                  4916.0
# East Asia                      1152.0
# Central Asia                   1000.0
# Australasia & Oceania           150.0

# %%
#WOUNDED IN EACH REGION
regw=data[["Region","Wounded"]].groupby("Region").sum().sort_values(by="Wounded",ascending=False)
regw
# Out:
#                               Wounded
# Region
# Middle East & North Africa   214308.0
# South Asia                   141360.0
# Sub-Saharan Africa            52857.0
# Southeast Asia                26259.0
# North America                 21531.0
# Western Europe                18332.0
# South America                 16704.0
# Eastern Europe                12045.0
# East Asia                      9213.0
# Central America & Caribbean    8991.0
# Central Asia                   2009.0
# Australasia & Oceania           260.0

# %%
fig=plt.figure()
ax0=fig.add_subplot(1,2,1)
ax1=fig.add_subplot(1,2,2)

#KILLED
regk.plot(kind="bar",color="Pink",figsize=(15,5), ax=ax0)
ax0.set_title("PEOPLE KILLED IN EACH REGION",fontsize=14)
ax0.set_xlabel("REGIONS",fontsize=12)
ax0.set_ylabel("NUMBER OF PEOPLE KILLED",fontsize=12)

#WOUNDED
regw.plot(kind="bar",color="LightGreen",figsize=(15,5), ax=ax1)
ax1.set_title("PEOPLE WOUNDED IN EACH REGION", fontsize=14)
ax1.set_xlabel("REGIONS",fontsize=12)
ax1.set_ylabel("NUMBER OF PEOPLE WOUNDED",fontsize=12)

plt.show()

# %% [markdown]
# 𝟯. 𝗖𝗢𝗨𝗡𝗧𝗥𝗬 𝗪𝗜𝗦𝗘 𝗔𝗧𝗧𝗔𝗖𝗞𝗦 - 𝗧𝗢𝗣 𝟭𝟬

# %% [markdown]
#      (𝑨) 𝑵𝑼𝑴𝑩𝑬𝑹 𝑶𝑭 𝑨𝑻𝑻𝑨𝑪𝑲𝑺 𝑰𝑵 𝑬𝑨𝑪𝑯 𝑪𝑶𝑼𝑵𝑻𝑹𝒀

# %%
ct=data["Country"].value_counts().head(10)
ct
# Out:
# Iraq              24636
# Pakistan          14368
# Afghanistan       12731
# India             11960
# Colombia           8306
# Philippines        6908
# Peru               6096
# El Salvador        5320
# United Kingdom     5235
# Turkey             4292
# Name: Country, dtype: int64

# %%
ct.plot(kind="bar",color="CornFlowerBlue",figsize=(13,5),fontsize=9)
plt.title("COUNTRY WISE ATTACKS",fontsize=14)
plt.xlabel("COUNTRIES",fontsize=12)
plt.xticks(fontsize=12)
plt.ylabel("NUMBER OF ATTACKS",fontsize=12)
plt.show()

# %% [markdown]
#      (𝑩) 𝑻𝑶𝑻𝑨𝑳 𝑪𝑨𝑺𝑼𝑳𝑨𝑻𝑰𝑬𝑺 (𝑲𝑰𝑳𝑳𝑬𝑫 + 𝑾𝑶𝑼𝑵𝑫𝑬𝑫) 𝑰𝑵 𝑬𝑨𝑪𝑯 𝑪𝑶𝑼𝑵𝑻𝑹𝒀

# %%
cnc=data[["Country","Casualty"]].groupby("Country").sum().sort_values(by="Casualty",ascending=False)
cnc.head(10)
# Out:
#                Casualty
# Country
# Iraq           213279.0
# Afghanistan     83661.0
# Pakistan        65860.0
# India           48321.0
# Nigeria         32921.0
# Sri Lanka       31091.0
# Syria           29338.0
# Colombia        25026.0
# United States   24473.0
# Philippines     22926.0

# %%
cnc[:10].plot(kind="bar",color="Orange",figsize=(13,5),fontsize=9)
plt.title("COUNTRY WISE CASUALTIES",fontsize=14)
plt.xlabel("COUNTRIES",fontsize=12)
plt.xticks(fontsize=12)
plt.ylabel("NUMBER OF CASUALTIES",fontsize=12)
plt.show()

# %% [markdown]
#      (𝑪) 𝑲𝑰𝑳𝑳𝑬𝑫 𝑨𝑵𝑫 𝑾𝑶𝑼𝑵𝑫𝑬𝑫 𝑰𝑵 𝑬𝑨𝑪𝑯 𝑪𝑶𝑼𝑵𝑻𝑹𝒀

# %%
#KILLED IN EACH COUNTRY
cnk=data[["Country","Killed"]].groupby("Country").sum().sort_values(by="Killed",ascending=False)
cnk.head(10)
# Out:
#               Killed
# Country
# Iraq         78589.0
# Afghanistan  39384.0
# Pakistan     23822.0
# Nigeria      22682.0
# India        19341.0
# Sri Lanka    15530.0
# Syria        15229.0
# Colombia     14698.0
# Peru         12771.0
# El Salvador  12053.0

# %%
#WOUNDED IN EACH COUNTRY
cnw=data[["Country","Wounded"]].groupby("Country").sum().sort_values(by="Wounded",ascending=False)
cnw.head(10)
# Out:
#                 Wounded
# Country
# Iraq           134690.0
# Afghanistan     44277.0
# Pakistan        42038.0
# India           28980.0
# United States   20702.0
# Sri Lanka       15561.0
# Syria           14109.0
# Philippines     13367.0
# Lebanon         10904.0
# Colombia        10328.0

# %%
fig=plt.figure()
ax0=fig.add_subplot(1,2,1)
ax1=fig.add_subplot(1,2,2)

#KILLED
cnk[:10].plot(kind="bar",color="Pink",figsize=(15,5), ax=ax0)
ax0.set_title("PEOPLE KILLED IN EACH COUNTRY",fontsize=14)
ax0.set_xlabel("COUNTRIES",fontsize=12)
ax0.set_ylabel("NUMBER OF PEOPLE KILLED",fontsize=12)

#WOUNDED
cnw[:10].plot(kind="bar",color="LightGreen",figsize=(15,5), ax=ax1)
ax1.set_title("PEOPLE WOUNDED IN EACH COUNTRY", fontsize=14)
ax1.set_xlabel("COUNTRIES",fontsize=12)
ax1.set_ylabel("NUMBER OF PEOPLE WOUNDED",fontsize=12)

plt.show()

# %% [markdown]
# 𝟰. 𝗖𝗜𝗧𝗬 𝗪𝗜𝗦𝗘 𝗔𝗧𝗧𝗔𝗖𝗞𝗦 - 𝗧𝗢𝗣 𝟭𝟬

# %% [markdown]
#      (𝑨) 𝑵𝑼𝑴𝑩𝑬𝑹 𝑶𝑭 𝑨𝑻𝑻𝑨𝑪𝑲𝑺 𝑰𝑵 𝑬𝑨𝑪𝑯 𝑪𝑰𝑻𝒀

# %%
city=data["City"].value_counts()[1:11]
city
# Out:
# Baghdad         7589
# Karachi         2652
# Lima            2359
# Mosul           2265
# Belfast         2171
# Santiago        1621
# Mogadishu       1581
# San Salvador    1558
# Istanbul        1048
# Athens          1019
# Name: City, dtype: int64

# %%
city.plot(kind="bar",color="CornFlowerBlue",figsize=(13,5),fontsize=9)
plt.title("CITY WISE ATTACKS",fontsize=14)
plt.xlabel("CITIES",fontsize=12)
plt.xticks(fontsize=12)
plt.ylabel("NUMBER OF ATTACKS",fontsize=12)
plt.show()

# %% [markdown]
#       (𝑩) 𝑻𝑶𝑻𝑨𝑳 𝑪𝑨𝑺𝑼𝑳𝑨𝑻𝑰𝑬𝑺 (𝑲𝑰𝑳𝑳𝑬𝑫 + 𝑾𝑶𝑼𝑵𝑫𝑬𝑫) 𝑰𝑵 𝑬𝑨𝑪𝑯 𝑪𝑰𝑻𝒀

# %%
cc=data[["City","Casualty"]].groupby("City").sum().sort_values(by="Casualty",ascending=False).drop("Unknown")
cc.head(10)
# Out:
#                Casualty
# City
# Baghdad         77876.0
# New York City   19619.0
# Mosul           12927.0
# Karachi          9376.0
# Mogadishu        8868.0
# Kabul            8466.0
# Beirut           7257.0
# Kirkuk           6636.0
# Colombo          5906.0
# Aleppo           5748.0

# %%
cc[:10].plot(kind="bar",color="Orange",figsize=(13,5),fontsize=9)
plt.title("CITY WISE CASUALTIES",fontsize=14)
plt.xlabel("CITIES",fontsize=12)
plt.xticks(fontsize=12)
plt.ylabel("NUMBER OF CASUALTIES",fontsize=12)
plt.show()

# %% [markdown]
#      (𝑪) 𝑲𝑰𝑳𝑳𝑬𝑫 𝑨𝑵𝑫 𝑾𝑶𝑼𝑵𝑫𝑬𝑫 𝑰𝑵 𝑬𝑨𝑪𝑯 𝑪𝑰𝑻𝒀

# %%
#KILLED IN EACH CITY
ck=data[["City","Killed"]].groupby("City").sum().sort_values(by="Killed",ascending=False).drop("Unknown")
ck.head(10)
# Out:
#                 Killed
# City
# Baghdad        21151.0
# Mosul           7140.0
# Mogadishu       3913.0
# Karachi         3688.0
# New York City   2838.0
# Tikrit          2679.0
# Kabul           2493.0
# Ramadi          2313.0
# Maiduguri       2235.0
# Aleppo          2125.0

# %%
#WOUNDED IN EACH CITY
cw=data[["City","Wounded"]].groupby("City").sum().sort_values(by="Wounded",ascending=False).drop("Unknown")
cw.head(10)
# Out:
#                Wounded
# City
# Baghdad        56725.0
# New York City  16781.0
# Kabul           5973.0
# Mosul           5787.0
# Karachi         5688.0
# Tokyo           5542.0
# Beirut          5341.0
# Nairobi         5024.0
# Kirkuk          5008.0
# Mogadishu       4955.0

# %%
fig=plt.figure()
ax0=fig.add_subplot(1,2,1)
ax1=fig.add_subplot(1,2,2)

#KILLED
ck[:10].plot(kind="bar",color="Pink",figsize=(15,5), ax=ax0)
ax0.set_title("PEOPLE KILLED IN EACH CITY",fontsize=14)
ax0.set_xlabel("CITIES",fontsize=12)
ax0.set_ylabel("NUMBER OF PEOPLE KILLED",fontsize=12)

#WOUNDED
cw[:10].plot(kind="bar",color="LightGreen",figsize=(15,5), ax=ax1)
ax1.set_title("PEOPLE WOUNDED IN EACH CITY", fontsize=14)
ax1.set_xlabel("CITIES",fontsize=12)
ax1.set_ylabel("NUMBER OF PEOPLE WOUNDED",fontsize=12)

plt.show()

# %% [markdown]
# 𝟱. 𝗧𝗘𝗥𝗥𝗢𝗥𝗜𝗦𝗧 𝗚𝗥𝗢𝗨𝗣 𝗪𝗜𝗦𝗘 𝗔𝗧𝗧𝗔𝗖𝗞𝗦 - 𝗧𝗢𝗣 𝟭𝟬

# %% [markdown]
#      (𝑨) 𝑵𝑼𝑴𝑩𝑬𝑹 𝑶𝑭 𝑨𝑻𝑻𝑨𝑪𝑲𝑺 𝑰𝑵 𝑬𝑨𝑪𝑯 𝑮𝑹𝑶𝑼𝑷

# %%
grp=data["Group Name"].value_counts()[1:10]
grp
# Out:
# Taliban                                             7478
# Islamic State of Iraq and the Levant (ISIL)         5613
# Shining Path (SL)                                   4555
# Farabundo Marti National Liberation Front (FMLN)    3351
# Al-Shabaab                                          3288
# New People's Army (NPA)                             2772
# Irish Republican Army (IRA)                         2671
# Revolutionary Armed Forces of Colombia (FARC)       2487
# Boko Haram                                          2418
# Name: Group Name, dtype: int64

# %%
grp.plot(kind="bar",color="CornFlowerBlue",figsize=(13,5),fontsize=9)
plt.title("GROUP WISE ATTACKS",fontsize=14)
plt.xlabel("TERRORIST GROUPS",fontsize=12)
plt.xticks(fontsize=12)
plt.ylabel("NUMBER OF ATTACKS",fontsize=12)
plt.show()

# %% [markdown]
#      (𝑩) 𝑻𝑶𝑻𝑨𝑳 𝑪𝑨𝑺𝑼𝑳𝑨𝑻𝑰𝑬𝑺 (𝑲𝑰𝑳𝑳𝑬𝑫 + 𝑾𝑶𝑼𝑵𝑫𝑬𝑫) 𝑰𝑵 𝑬𝑨𝑪𝑯 𝑮𝑹𝑶𝑼𝑷

# %%
gc=data[["Group Name","Casualty"]].groupby("Group Name").sum().sort_values(by="Casualty",ascending=False).drop("Unknown")
gc.head(10)
# Out:
#                                                   Casualty
# Group Name
# Islamic State of Iraq and the Levant (ISIL)        69595.0
# Taliban                                            57342.0
# Boko Haram                                         29801.0
# Al-Qaida                                           28372.0
# Liberation Tigers of Tamil Eelam (LTTE)            22020.0
# Al-Shabaab                                         16954.0
# Tehrik-i-Taliban Pakistan (TTP)                    15574.0
# Al-Qaida in Iraq                                   14724.0
# Shining Path (SL)                                  14632.0
# Farabundo Marti National Liberation Front (FMLN)   12130.0

# %%
gc.head(10).plot(kind="bar",color="Orange",figsize=(13,5),fontsize=9)
plt.title("CASUATIES OF EACH GROUP",fontsize=14)
plt.xlabel("TERRORIST GROUPS",fontsize=12)
plt.xticks(fontsize=12)
plt.ylabel("NUMBER OF CASUALTIES",fontsize=12)
plt.show()

# %% [markdown]
#      (𝑪) 𝑲𝑰𝑳𝑳𝑬𝑫 𝑨𝑵𝑫 𝑾𝑶𝑼𝑵𝑫𝑬𝑫 𝑰𝑵 𝑬𝑨𝑪𝑯 𝑮𝑹𝑶𝑼𝑷

# %%
#KILLED IN EACH GROUP
gk=data[["Group Name","Killed"]].groupby("Group Name").sum().sort_values(by="Killed",ascending=False).drop("Unknown")
gk.head(10)
# Out:
#                                                    Killed
# Group Name
# Islamic State of Iraq and the Levant (ISIL)       38923.0
# Taliban                                           29410.0
# Boko Haram                                        20328.0
# Shining Path (SL)                                 11601.0
# Liberation Tigers of Tamil Eelam (LTTE)           10989.0
# Al-Shabaab                                         9330.0
# Farabundo Marti National Liberation Front (FMLN)   8065.0
# Nicaraguan Democratic Force (FDN)                  6662.0
# Tehrik-i-Taliban Pakistan (TTP)                    6042.0
# Revolutionary Armed Forces of Colombia (FARC)      5661.0

# %%
#WOUNDED IN EACH GROUP
gw=data[["Group Name","Wounded"]].groupby("Group Name").sum().sort_values(by="Wounded",ascending=False).drop("Unknown")
gw.head(10)
# Out:
#                                              Wounded
# Group Name
# Islamic State of Iraq and the Levant (ISIL)  30672.0
# Taliban                                      27932.0
# Al-Qaida                                     24512.0
# Liberation Tigers of Tamil Eelam (LTTE)      11031.0
# Al-Qaida in Iraq                             10343.0
# Tehrik-i-Taliban Pakistan (TTP)               9532.0
# Boko Haram                                    9473.0
# Al-Shabaab                                    7624.0
# Aum Shinri Kyo                                6003.0
# Kurdistan Workers' Party (PKK)                4908.0

# %%
fig=plt.figure()
ax0=fig.add_subplot(1,2,1)
ax1=fig.add_subplot(1,2,2)

#KILLED
gk[:10].plot(kind="bar",color="Pink",figsize=(15,5), ax=ax0)
ax0.set_title("PEOPLE KILLED IN EACH GROUP",fontsize=14)
ax0.set_xlabel("TERRORIST GROUPS",fontsize=12)
ax0.set_ylabel("NUMBER OF PEOPLE KILLED",fontsize=12)

#WOUNDED
gw[:10].plot(kind="bar",color="LightGreen",figsize=(15,5), ax=ax1)
ax1.set_title("PEOPLE WOUNDED IN EACH GROUP", fontsize=14)
ax1.set_xlabel("TERRORIST GROUPS",fontsize=12)
ax1.set_ylabel("NUMBER OF PEOPLE WOUNDED",fontsize=12)

plt.show()

# %% [markdown]
# 𝟲. 𝗔𝗧𝗧𝗔𝗖𝗞 𝗧𝗬𝗣𝗘 𝗪𝗜𝗦𝗘 𝗔𝗧𝗧𝗔𝗖𝗞𝗦 - 𝗧𝗢𝗣 𝟭𝟬

# %% [markdown]
#      (𝑨) 𝑵𝑼𝑴𝑩𝑬𝑹 𝑶𝑭 𝑨𝑻𝑻𝑨𝑪𝑲𝑺 𝑰𝑵 𝑬𝑨𝑪𝑯 𝑨𝑻𝑻𝑨𝑪𝑲 𝑻𝒀𝑷𝑬

# %%
at=data["Attack Type"].value_counts()
at
# Out:
# Bombing/Explosion                      88255
# Armed Assault                          42669
# Assassination                          19312
# Hostage Taking (Kidnapping)            11158
# Facility/Infrastructure Attack         10356
# Unknown                                 7276
# Unarmed Assault                         1015
# Hostage Taking (Barricade Incident)      991
# Hijacking                                659
# Name: Attack Type, dtype: int64

# %%
at.plot(kind="bar",color="CornFlowerBlue",figsize=(13,5),fontsize=9)
plt.title("TYPES OF ATTACKS",fontsize=14)
plt.xlabel("ATTACK TYPES",fontsize=12)
plt.xticks(fontsize=12)
plt.ylabel("NUMBER OF ATTACKS",fontsize=12)
plt.show()

# %% [markdown]
#      (𝑩) 𝑻𝑶𝑻𝑨𝑳 𝑪𝑨𝑺𝑼𝑳𝑨𝑻𝑰𝑬𝑺 (𝑲𝑰𝑳𝑳𝑬𝑫 + 𝑾𝑶𝑼𝑵𝑫𝑬𝑫) 𝑰𝑵 𝑬𝑨𝑪𝑯 𝑨𝑻𝑻𝑨𝑪𝑲 𝑻𝒀𝑷𝑬

# %%
ac=data[["Attack Type","Casualty"]].groupby("Attack Type").sum().sort_values(by="Casualty",ascending=False)
ac
# Out:
#                                      Casualty
# Attack Type
# Bombing/Explosion                    530007.0
# Armed Assault                        237663.0
# Unknown                               47106.0
# Assassination                         38807.0
# Hostage Taking (Kidnapping)           30677.0
# Hijacking                             20719.0
# Unarmed Assault                       14907.0
# Hostage Taking (Barricade Incident)    8444.0
# Facility/Infrastructure Attack         7407.0

# %%
ac.plot(kind="bar",color="Orange",figsize=(13,5),fontsize=9)
plt.title("CASUATIES OF EACH ATTACK TYPE",fontsize=14)
plt.xlabel("ATTACK TYPES",fontsize=12)
plt.xticks(fontsize=12)
plt.ylabel("NUMBER OF CASUALTIES",fontsize=12)
plt.show()

# %% [markdown]
#      (𝑪) 𝑲𝑰𝑳𝑳𝑬𝑫 𝑨𝑵𝑫 𝑾𝑶𝑼𝑵𝑫𝑬𝑫 𝑰𝑵 𝑬𝑨𝑪𝑯 𝑨𝑻𝑻𝑨𝑪𝑲 𝑻𝒀𝑷𝑬

# %%
#KILLED IN EACH ATTACK TYPE
ak=data[["Attack Type","Killed"]].groupby("Attack Type").sum().sort_values(by="Killed",ascending=False)
ak
# Out:
#                                        Killed
# Attack Type
# Armed Assault                        160297.0
# Bombing/Explosion                    157321.0
# Unknown                               32381.0
# Assassination                         24920.0
# Hostage Taking (Kidnapping)           24231.0
# Hostage Taking (Barricade Incident)    4478.0
# Hijacking                              3718.0
# Facility/Infrastructure Attack         3642.0
# Unarmed Assault                         880.0

# %%
#WOUNDED IN EACH ATTACK TYPE
aw=data[["Attack Type","Wounded"]].groupby("Attack Type").sum().sort_values(by="Wounded",ascending=False)
aw
# Out:
#                                       Wounded
# Attack Type
# Bombing/Explosion                    372686.0
# Armed Assault                         77366.0
# Hijacking                             17001.0
# Unknown                               14725.0
# Unarmed Assault                       14027.0
# Assassination                         13887.0
# Hostage Taking (Kidnapping)            6446.0
# Hostage Taking (Barricade Incident)    3966.0
# Facility/Infrastructure Attack         3765.0

# %%
fig=plt.figure()
ax0=fig.add_subplot(1,2,1)
ax1=fig.add_subplot(1,2,2)

#KILLED
ak.plot(kind="bar",color="Pink",figsize=(15,5), ax=ax0)
ax0.set_title("PEOPLE KILLED IN EACH ATTACK TYPE",fontsize=14)
ax0.set_xlabel("ATTACK TYPES",fontsize=12)
ax0.set_ylabel("NUMBER OF PEOPLE KILLED",fontsize=12)

#WOUNDED
aw.plot(kind="bar",color="LightGreen",figsize=(15,5), ax=ax1)
ax1.set_title("PEOPLE WOUNDED IN EACH ATTACK TYPE", fontsize=14)
ax1.set_xlabel("ATTACK TYPES",fontsize=12)
ax1.set_ylabel("NUMBER OF PEOPLE WOUNDED",fontsize=12)

plt.show()

# %% [markdown]
# 𝟳. 𝗧𝗔𝗥𝗚𝗘𝗧 𝗧𝗬𝗣𝗘 𝗪𝗜𝗦𝗘 𝗔𝗧𝗧𝗔𝗖𝗞𝗦 - 𝗧𝗢𝗣 𝟭𝟬

# %% [markdown]
#      (𝑨) 𝑵𝑼𝑴𝑩𝑬𝑹 𝑶𝑭 𝑨𝑻𝑻𝑨𝑪𝑲𝑺 𝑰𝑵 𝑬𝑨𝑪𝑯 𝑻𝑨𝑹𝑮𝑬𝑻 𝑻𝒀𝑷𝑬

# %%
ta=data["Target Type"].value_counts()
ta
# Out:
# Private Citizens & Property       43511
# Military                          27984
# Police                            24506
# Government (General)              21283
# Business                          20669
# Transportation                     6799
# Utilities                          6023
# Unknown                            5898
# Religious Figures/Institutions     4440
# Educational Institution            4322
# Government (Diplomatic)            3573
# Terrorists/Non-State Militia       3039
# Journalists & Media                2948
# Violent Political Party            1866
# Airports & Aircraft                1343
# Telecommunication                  1009
# NGO                                 970
# Tourists                            440
# Maritime                            351
# Food or Water Supply                317
# Abortion Related                    263
# Other                               137
# Name: Target Type, dtype: int64

# %%
ta.plot(kind="bar",color="CornFlowerBlue",figsize=(13,5),fontsize=9)
plt.title("TYPES OF TARGETS",fontsize=14)
plt.xlabel("TARGET TYPES",fontsize=12)
plt.xticks(fontsize=12)
plt.ylabel("NUMBER OF ATTACKS",fontsize=12)
plt.show()

# %% [markdown]
#      (𝑩) 𝑻𝑶𝑻𝑨𝑳 𝑪𝑨𝑺𝑼𝑳𝑨𝑻𝑰𝑬𝑺 (𝑲𝑰𝑳𝑳𝑬𝑫 + 𝑾𝑶𝑼𝑵𝑫𝑬𝑫) 𝑰𝑵 𝑬𝑨𝑪𝑯 𝑻𝑨𝑹𝑮𝑬𝑻 𝑻𝒀𝑷𝑬

# %%
tc=data[["Target Type","Casualty"]].groupby("Target Type").sum().sort_values(by="Casualty",ascending=False)
tc
# Out:
#                                 Casualty
# Target Type
# Private Citizens & Property     319176.0
# Military                        177085.0
# Police                          118407.0
# Business                         78018.0
# Government (General)             67255.0
# Transportation                   54595.0
# Religious Figures/Institutions   37890.0
# Terrorists/Non-State Militia     17311.0
# Educational Institution          13972.0
# Government (Diplomatic)          13398.0
# Violent Political Party           8920.0
# Unknown                           7888.0
# Airports & Aircraft               7245.0
# Journalists & Media               3297.0
# Utilities                         3227.0
# Maritime                          2099.0
# Tourists                          2048.0
# NGO                               1950.0
# Telecommunication                  679.0
# Other                              674.0
# Food or Water Supply               547.0
# ...

# %%
tc.plot(kind="bar",color="Orange",figsize=(13,5),fontsize=9)
plt.title("CASUATIES OF EACH TRAGET TYPE",fontsize=14)
plt.xlabel("TARGET TYPES",fontsize=12)
plt.xticks(fontsize=12)
plt.ylabel("NUMBER OF CASUALTIES",fontsize=12)
plt.show()

# %% [markdown]
#      (𝑪) 𝑲𝑰𝑳𝑳𝑬𝑫 𝑨𝑵𝑫 𝑾𝑶𝑼𝑵𝑫𝑬𝑫 𝑰𝑵 𝑬𝑨𝑪𝑯 𝑻𝑨𝑹𝑮𝑬𝑻 𝑻𝒀𝑷𝑬

# %%
#KILLED IN EACH TARGET TYPE
tk=data[["Target Type","Killed"]].groupby("Target Type").sum().sort_values(by="Killed",ascending=False)
tk
# Out:
#                                   Killed
# Target Type
# Private Citizens & Property     140504.0
# Military                        106047.0
# Police                           53704.0
# Government (General)             26071.0
# Business                         23487.0
# Transportation                   13916.0
# Religious Figures/Institutions   13413.0
# Terrorists/Non-State Militia      9088.0
# Unknown                           4329.0
# Airports & Aircraft               3767.0
# Educational Institution           3745.0
# Violent Political Party           3617.0
# Government (Diplomatic)           3039.0
# Utilities                         1874.0
# Journalists & Media               1501.0
# Maritime                          1191.0
# NGO                               1057.0
# Tourists                           758.0
# Food or Water Supply               313.0
# Other                              255.0
# Telecommunication                  182.0
# ...

# %%
#WOUNDED IN EACH TARGET TYPE
tw=data[["Target Type","Wounded"]].groupby("Target Type").sum().sort_values(by="Wounded",ascending=False)
tw
# Out:
#                                  Wounded
# Target Type
# Private Citizens & Property     178672.0
# Military                         71038.0
# Police                           64703.0
# Business                         54531.0
# Government (General)             41184.0
# Transportation                   40679.0
# Religious Figures/Institutions   24477.0
# Government (Diplomatic)          10359.0
# Educational Institution          10227.0
# Terrorists/Non-State Militia      8223.0
# Violent Political Party           5303.0
# Unknown                           3559.0
# Airports & Aircraft               3478.0
# Journalists & Media               1796.0
# Utilities                         1353.0
# Tourists                          1290.0
# Maritime                           908.0
# NGO                                893.0
# Telecommunication                  497.0
# Other                              419.0
# Food or Water Supply               234.0
# ...

# %%
fig=plt.figure()
ax0=fig.add_subplot(1,2,1)
ax1=fig.add_subplot(1,2,2)

#KILLED
tk.plot(kind="bar",color="Pink",figsize=(15,5), ax=ax0)
ax0.set_title("PEOPLE KILLED IN EACH TARGET TYPE",fontsize=14)
ax0.set_xlabel("TARGET TYPES",fontsize=12)
ax0.set_ylabel("NUMBER OF PEOPLE KILLED",fontsize=12)

#WOUNDED
tw.plot(kind="bar",color="LightGreen",figsize=(15,5), ax=ax1)
ax1.set_title("PEOPLE WOUNDED IN EACH TARGET TYPE", fontsize=14)
ax1.set_xlabel("TARGET TYPES",fontsize=12)
ax1.set_ylabel("NUMBER OF PEOPLE WOUNDED",fontsize=12)

plt.show()

# %% [markdown]
# 𝟴. 𝗚𝗥𝗢𝗨𝗣 + 𝗖𝗢𝗨𝗡𝗧𝗥𝗬 𝗪𝗜𝗦𝗘 - 𝗧𝗢𝗣 𝟭𝟬

# %% [markdown]
#      (𝑨) 𝑺𝑶𝑹𝑻𝑰𝑵𝑮 𝑵𝑼𝑴𝑩𝑬𝑹 𝑶𝑭 𝑨𝑻𝑻𝑨𝑪𝑲𝑺

# %%
gca=data[["Group Name","Country"]].value_counts().drop("Unknown")
gca.head(10)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_10620\2809923545.py:1: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   gca=data[["Group Name","Country"]].value_counts().drop("Unknown")
# Group Name                                        Country
# Taliban                                           Afghanistan       7423
# Islamic State of Iraq and the Levant (ISIL)       Iraq              4797
# Shining Path (SL)                                 Peru              4541
# Farabundo Marti National Liberation Front (FMLN)  El Salvador       3330
# Al-Shabaab                                        Somalia           2867
# New People's Army (NPA)                           Philippines       2770
# Irish Republican Army (IRA)                       United Kingdom    2575
# Revolutionary Armed Forces of Colombia (FARC)     Colombia          2468
# Kurdistan Workers' Party (PKK)                    Turkey            2109
# ...

# %%
gca.head(10).plot(kind="bar",color="CornFlowerBlue",figsize=(13,5),fontsize=9)
plt.title("COUNTRIES WITH MOST ATTACKS BY A PARTICULAR GROUP",fontsize=14)
plt.xlabel("TERRORIST GROUP, COUNTRY",fontsize=12)
plt.xticks(fontsize=12)
plt.ylabel("NUMBER OF ATTACKS",fontsize=12)
plt.show()

# %% [markdown]
#      (𝑩) 𝑺𝑶𝑹𝑻𝑰𝑵𝑮 𝑵𝑼𝑴𝑩𝑬𝑹 𝑶𝑭 𝑪𝑨𝑺𝑼𝑨𝑳𝑻𝑰𝑬𝑺

# %%
gcc=data[["Group Name","Country","Casualty"]].groupby(["Group Name","Country"],axis=0).sum().sort_values(by="Casualty",ascending=False).drop("Unknown").head(10)
gcc
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_10620\2708838124.py:1: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   gcc=data[["Group Name","Country","Casualty"]].groupby(["Group Name","Country"],axis=0).sum().sort_values(by="Casualty",ascending=False).drop("Unknown").head(10)
#                                                                 Casualty
# Group Name                                       Country
# Taliban                                          Afghanistan     57140.0
# Islamic State of Iraq and the Levant (ISIL)      Iraq            54755.0
# Boko Haram                                       Nigeria         24588.0
# Liberation Tigers of Tamil Eelam (LTTE)          Sri Lanka       21919.0
# Al-Qaida                                         United States   19494.0
# Tehrik-i-Taliban Pakistan (TTP)                  Pakistan        15532.0
# Shining Path (SL)                                Peru            14625.0
# ...

# %%
gcc.plot(kind="bar",color="Orange",figsize=(13,5),fontsize=9)
plt.title("COUNTRIES WITH MOST CASUALTIES BY A PARTICULAR GROUP",fontsize=14)
plt.xlabel("TERRORIST GROUP, COUNTRY",fontsize=12)
plt.xticks(fontsize=12)
plt.ylabel("NUMBER OF CASUALTIES",fontsize=12)
plt.show()

# %% [markdown]
#      (𝑪) 𝑺𝑶𝑹𝑻𝑰𝑵𝑮 𝑵𝑼𝑴𝑩𝑬𝑹 𝑶𝑭 𝑷𝑬𝑶𝑷𝑳𝑬 𝑲𝑰𝑳𝑳𝑬𝑫 𝑨𝑵𝑫 𝑾𝑶𝑼𝑵𝑫𝑬𝑫

# %%
#KILLED BY EACH GROUP AND COUNTRY
gck=data[["Group Name","Country","Killed"]].groupby(["Group Name","Country"],axis=0).sum().sort_values(by="Killed",ascending=False).drop("Unknown").head(10)
gck
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_10620\2506721537.py:2: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   gck=data[["Group Name","Country","Killed"]].groupby(["Group Name","Country"],axis=0).sum().sort_values(by="Killed",ascending=False).drop("Unknown").head(10)
#                                                                Killed
# Group Name                                       Country
# Islamic State of Iraq and the Levant (ISIL)      Iraq         31058.0
# Taliban                                          Afghanistan  29269.0
# Boko Haram                                       Nigeria      16917.0
# Shining Path (SL)                                Peru         11595.0
# Liberation Tigers of Tamil Eelam (LTTE)          Sri Lanka    10928.0
# Al-Shabaab                                       Somalia       8176.0
# Farabundo Marti National Liberation Front (FMLN) El Salvador   8019.0
# ...

# %%
#WOUNDED BY EACH GROUP AND COUNTRY
gcw=data[["Group Name","Country","Wounded"]].groupby(["Group Name","Country"],axis=0).sum().sort_values(by="Wounded",ascending=False).drop("Unknown").head(10)
gcw
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_10620\1414105956.py:2: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   gcw=data[["Group Name","Country","Wounded"]].groupby(["Group Name","Country"],axis=0).sum().sort_values(by="Wounded",ascending=False).drop("Unknown").head(10)
#                                                            Wounded
# Group Name                                  Country
# Taliban                                     Afghanistan    27871.0
# Islamic State of Iraq and the Levant (ISIL) Iraq           23697.0
# Al-Qaida                                    United States  16493.0
# Liberation Tigers of Tamil Eelam (LTTE)     Sri Lanka      10991.0
# Al-Qaida in Iraq                            Iraq           10075.0
# Tehrik-i-Taliban Pakistan (TTP)             Pakistan        9518.0
# Boko Haram                                  Nigeria         7671.0
# ...

# %%
fig=plt.figure()
ax0=fig.add_subplot(1,2,1)
ax1=fig.add_subplot(1,2,2)

#KILLED
gck.plot(kind="bar",color="Pink",figsize=(15,5), ax=ax0)
ax0.set_title("COUNTRIES WITH MOST PEOPLE KILLED BY A PARTICULAR GROUP",fontsize=13)
ax0.set_xlabel("TERRORIST GROUP, COUNTRY",fontsize=12)
ax0.set_ylabel("NUMBER OF PEOPLE KILLED",fontsize=12)

#WOUNDED
gcw.plot(kind="bar",color="LightGreen",figsize=(15,5), ax=ax1)
ax1.set_title("COUNTRIES WITH MOST PEOPLE WOUNDED BY A PARTICULAR GROUP", fontsize=13)
ax1.set_xlabel("TERRORIST GROUP, COUNTRY",fontsize=12)
ax1.set_ylabel("NUMBER OF PEOPLE WOUNDED",fontsize=12)

plt.show()

# %% [markdown]
# 𝟵. 𝗛𝗨𝗠𝗔𝗡𝗜𝗧𝗬 𝗔𝗙𝗙𝗘𝗖𝗧𝗘𝗗 (𝗪𝗢𝗥𝗟𝗗 𝗪𝗜𝗗𝗘) 𝗕𝗬 𝗧𝗘𝗥𝗥𝗢𝗥𝗜𝗦𝗧 𝗔𝗧𝗧𝗔𝗖𝗞𝗦 𝗙𝗥𝗢𝗠 𝟭𝟵𝟳𝟬 𝗧𝗢 𝟮𝟬𝟭𝟳

# %% [markdown]
#      (𝑨) 𝑻𝑶𝑻𝑨𝑳 𝑪𝑨𝑺𝑼𝑳𝑨𝑻𝑰𝑬𝑺 (𝑲𝑰𝑳𝑳𝑬𝑫 + 𝑾𝑶𝑼𝑵𝑫𝑬𝑫) 𝑫𝑼𝑬 𝑻𝑶 𝑻𝑬𝑹𝑹𝑶𝑹𝑰𝑺𝑻 𝑨𝑻𝑻𝑨𝑪𝑲

# %%
casualty=data.loc[:,"Casualty"].sum()
print("Total number of Casualties due to the Terrorist Attacks from 1970 to 2017 across the world : ", casualty)
# Out:
# Total number of Casualties due to the Terrorist Attacks from 1970 to 2017 across the world :  935737.0

# %% [markdown]
#      (𝑩) 𝑲𝑰𝑳𝑳𝑬𝑫 𝑨𝑵𝑫 𝑾𝑶𝑼𝑵𝑫𝑬𝑫 𝑫𝑼𝑬 𝑻𝑶 𝑻𝑬𝑹𝑹𝑶𝑹𝑰𝑺𝑻 𝑨𝑻𝑻𝑨𝑪𝑲

# %%
#KILLED DUE TO TERRORIST ATTACKS
kill=data.loc[:,"Killed"].sum()
print("Total number of people killed due to Terrorist Attacks from 1970 to 2017 across the world : ", kill)
# Out:
# Total number of people killed due to Terrorist Attacks from 1970 to 2017 across the world :  411868.0

# %%
#WOUNDED DUE TO TERRORIST ATTACKS
wound=data.loc[:,"Wounded"].sum()
print("Total number of people wounded due to Terrorist Attacks from 1970 to 2017 across the world : ", wound)
# Out:
# Total number of people wounded due to Terrorist Attacks from 1970 to 2017 across the world :  523869.0

# %% [markdown]
#                                 𝗢𝗕𝗦𝗘𝗥𝗩𝗔𝗧𝗜𝗢𝗡 𝗔𝗡𝗗 𝗖𝗢𝗡𝗖𝗟𝗨𝗦𝗜𝗢𝗡:
#
#     𝟭. 𝗬𝗘𝗔𝗥 𝗪𝗜𝗦𝗘 𝗔𝗧𝗧𝗔𝗖𝗞𝗦 :
#        (𝗶) 𝗔𝗧𝗧𝗔𝗖𝗞𝗦 :
#           (𝗮) 𝗠𝗢𝗦𝗧 𝗡𝗨𝗠𝗕𝗘𝗥 𝗢𝗙 𝗔𝗧𝗧𝗔𝗖𝗞𝗦  : 𝟭𝟲𝟵𝟬𝟯 𝗶𝗻 𝟮𝟬𝟭𝟰
#           (𝗯) 𝗟𝗘𝗔𝗦𝗧 𝗡𝗨𝗠𝗕𝗘𝗥 𝗢𝗙 𝗔𝗧𝗧𝗔𝗖𝗞𝗦 : 𝟰𝟳𝟭 𝗶𝗻 𝟭𝟵𝟳𝟭
#        (𝗶𝗶) 𝗖𝗔𝗦𝗨𝗔𝗟𝗧𝗜𝗘𝗦 :
#           (𝗮) 𝗠𝗢𝗦𝗧 𝗡𝗨𝗠𝗕𝗘𝗥 𝗢𝗙 𝗖𝗔𝗦𝗨𝗔𝗟𝗧𝗜𝗘𝗦 : 𝟴𝟱𝟲𝟭𝟴 𝗶𝗻 𝟮𝟬𝟭𝟰
#           (𝗯) 𝗟𝗘𝗔𝗦𝗧 𝗡𝗨𝗠𝗕𝗘𝗥 𝗢𝗙 𝗖𝗔𝗦𝗨𝗔𝗟𝗧𝗜𝗘𝗦 : 𝟮𝟱𝟱 𝗶𝗻 𝟭𝟵𝟳𝟭
#       (𝗶𝗶𝗶) 𝗞𝗜𝗟𝗟𝗘𝗗 :
#           (𝗮) 𝗠𝗢𝗦𝗧 𝗡𝗨𝗠𝗕𝗘𝗥 𝗢𝗙 𝗣𝗘𝗢𝗣𝗟𝗘 𝗞𝗜𝗟𝗟𝗘𝗗 : 𝟰𝟰𝟰𝟵𝟬 𝗶𝗻 𝟮𝟬𝟭𝟰
#           (𝗯) 𝗟𝗘𝗔𝗦𝗧 𝗡𝗨𝗠𝗕𝗘𝗥 𝗢𝗙 𝗣𝗘𝗢𝗣𝗟𝗘 𝗞𝗜𝗟𝗟𝗘𝗗 : 𝟭𝟳𝟯 𝗶𝗻 𝟭𝟵𝟳𝟭
#       (𝗶𝘃) 𝗪𝗢𝗨𝗡𝗗𝗘𝗗 :
#           (𝗮) 𝗠𝗢𝗦𝗧 𝗡𝗨𝗠𝗕𝗘𝗥 𝗢𝗙 𝗣𝗘𝗢𝗣𝗟𝗘 𝗪𝗢𝗨𝗡𝗗𝗘𝗗: 𝟰𝟰𝟬𝟰𝟯 𝗶𝗻 𝟮𝟬𝟭𝟱
#           (𝗯) 𝗟𝗘𝗔𝗦𝗧 𝗡𝗨𝗠𝗕𝗘𝗥 𝗢𝗙 𝗣𝗘𝗢𝗣𝗟𝗘 𝗪𝗢𝗨𝗡𝗗𝗘𝗗 : 𝟴𝟮 𝗶𝗻 𝟭𝟵𝟳𝟭
#
#     𝟮. 𝗥𝗘𝗚𝗜𝗢𝗡 𝗪𝗜𝗦𝗘 𝗔𝗧𝗧𝗔𝗖𝗞𝗦 :
#        (𝗶) 𝗔𝗧𝗧𝗔𝗖𝗞𝗦 :
#           (𝗮) 𝗠𝗢𝗦𝗧 𝗡𝗨𝗠𝗕𝗘𝗥 𝗢𝗙 𝗔𝗧𝗧𝗔𝗖𝗞𝗦 : 𝟱𝟬𝟰𝟳𝟰 𝗶𝗻 "𝗠𝗶𝗱𝗱𝗹𝗲 𝗘𝗮𝘀𝘁 𝗮𝗻𝗱 𝗡𝗼𝗿𝘁𝗵 𝗔𝗳𝗿𝗶𝗰𝗮"
#           (𝗯) 𝗟𝗘𝗔𝗦𝗧 𝗡𝗨𝗠𝗕𝗘𝗥 𝗢𝗙 𝗔𝗧𝗧𝗔𝗖𝗞𝗦 : 𝟮𝟴𝟮 𝗶𝗻 "𝗔𝘂𝘀𝘁𝗿𝗮𝗹𝗮𝘀𝗶𝗮 𝗮𝗻𝗱 𝗢𝗰𝗲𝗮𝗻𝗶𝗮"
#       (𝗶𝗶) 𝗖𝗔𝗦𝗨𝗔𝗟𝗧𝗜𝗘𝗦 :
#           (𝗮) 𝗠𝗢𝗦𝗧 𝗡𝗨𝗠𝗕𝗘𝗥 𝗢𝗙 𝗖𝗔𝗦𝗨𝗔𝗟𝗧𝗜𝗘𝗦 : 𝟯𝟱𝟭𝟵𝟱𝟬 𝗶𝗻 "𝗠𝗶𝗱𝗱𝗹𝗲 𝗘𝗮𝘀𝘁 𝗮𝗻𝗱 𝗡𝗼𝗿𝘁𝗵 𝗔𝗳𝗿𝗶𝗰𝗮"
#           (𝗯) 𝗟𝗘𝗔𝗦𝗧 𝗡𝗨𝗠𝗕𝗘𝗥 𝗢𝗙 𝗖𝗔𝗦𝗨𝗔𝗟𝗧𝗜𝗘𝗦 : 𝟰𝟭𝟬 𝗶𝗻 "𝗔𝘂𝘀𝘁𝗿𝗮𝗹𝗮𝘀𝗶𝗮 𝗮𝗻𝗱 𝗢𝗰𝗲𝗮𝗻𝗶𝗮"
#       (𝗶𝗶𝗶) 𝗞𝗜𝗟𝗟𝗘𝗗 :
#           (𝗮) 𝗠𝗢𝗦𝗧 𝗡𝗨𝗠𝗕𝗘𝗥 𝗢𝗙 𝗣𝗘𝗢𝗣𝗟𝗘 𝗞𝗜𝗟𝗟𝗘𝗗 : 𝟭𝟯𝟳𝟲𝟰𝟮 𝗶𝗻 "𝗠𝗶𝗱𝗱𝗹𝗲 𝗘𝗮𝘀𝘁 𝗮𝗻𝗱 𝗡𝗼𝗿𝘁𝗵 𝗔𝗳𝗿𝗶𝗰𝗮"
#           (𝗯) 𝗟𝗘𝗔𝗦𝗧 𝗡𝗨𝗠𝗕𝗘𝗥 𝗢𝗙 𝗣𝗘𝗢𝗣𝗟𝗘 𝗞𝗜𝗟𝗟𝗘𝗗 : 𝟭𝟱𝟬 𝗶𝗻 "𝗔𝘂𝘀𝘁𝗿𝗮𝗹𝗮𝘀𝗶𝗮 𝗮𝗻𝗱 𝗢𝗰𝗲𝗮𝗻𝗶𝗮"
#       (𝗶𝘃) 𝗪𝗢𝗨𝗡𝗗𝗘𝗗