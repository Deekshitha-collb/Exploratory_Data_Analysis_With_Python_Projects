# %% [markdown]
# 𝐄𝐗𝗣𝗟𝗢𝗥𝗔𝗧𝗢𝗥𝗬 𝗗𝗔𝗧𝗔 𝗔𝗡𝗔𝗟𝗬𝗦𝗜𝗦 - 𝐓𝐈𝐊𝐓𝐎𝐊 𝐏𝐎𝐏𝐔𝐋𝐀𝐑 𝐒𝐎𝐍𝐆𝐒
#
# 𝐃𝐀𝐓𝐀𝐒𝐄𝐓 : 𝐓𝐢𝐤𝐭𝐨𝐤𝐏𝐨𝐩𝐮𝐥𝐚𝐫𝐒𝐨𝐧𝐠𝐬𝐃𝐚𝐭𝐚𝐬𝐞𝐭(𝐡𝐭𝐭𝐩𝐬://𝐰𝐰𝐰.𝐤𝐚𝐠𝐠𝐥𝐞.𝐜𝐨𝐦/𝐝𝐚𝐭𝐚𝐬𝐞𝐭𝐬/𝐬𝐯𝐞𝐭𝐚𝟏𝟓𝟏/𝐭𝐢𝐤𝐭𝐨𝐤-𝐩𝐨𝐩𝐮𝐥𝐚𝐫-𝐬𝐨𝐧𝐠𝐬-𝟐𝟎𝟏𝟗)019)

# %% [markdown]
# 𝑰𝑴𝑷𝑶𝑹𝑻𝑰𝑵𝑮 𝑵𝑬𝑪𝑬𝑺𝑺𝑨𝑹𝒀 𝑳𝑰𝑩𝑹𝑨𝑹𝑰𝑬𝑺

# %%
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
print("Imported Sucessfully.")
# Out:
# C:\Users\HP\AppData\Local\Programs\Python\Python39\lib\site-packages\scipy\__init__.py:155: UserWarning: A NumPy version >=1.18.5 and <1.25.0 is required for this version of SciPy (detected version 1.25.2
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# Imported Sucessfully.

# %% [markdown]
# 𝑳𝑶𝑨𝑫𝑰𝑵𝑮 𝑻𝑯𝑬 𝑫𝑨𝑻𝑨𝑺𝑬𝑻

# %%
data = pd.read_csv("C:/Users/HP/Downloads/TikTok_songs_2019.csv", encoding="latin1")
print("Tiktok Popular Songs Data Loaded Successfully.")
# Out:
# Tiktok Popular Songs Data Loaded Successfully.

# %% [markdown]
# 𝑫𝑨𝑻𝑨 𝑬𝑿𝑷𝑳𝑶𝑹𝑨𝑻𝑰𝑶𝑵 𝑨𝑵𝑫 𝑨𝑵𝑨𝑳𝒀𝑺𝑰𝑺

# %%
# DISAPLY FIRST FEW ROWS IN THE DATASET

data.head()
# Out:
#              track_name                 artist_name  artist_pop  \
# 0              Shake It               Metro Station          53
# 1      Chinese New Year                       SALES          61
# 2        Baby I'm Yours                    Breakbot          57
# 3            The Git Up                Blanco Brown          60
# 4  Say Hey (I Love You)  Michael Franti & Spearhead          58
#
#                album  track_pop  danceability  energy  loudness  mode  key  \
# 0      Metro Station         68         0.618   0.955    -3.836     1    4
# 1         SALES - EP         53         0.744   0.845    -7.422     0    4
# 2       By Your Side         69         0.829   0.792    -3.755     0    2
# 3         The Git Up          2         0.847   0.678    -8.635     1    9
# 4  All Rebel Rockers          0         0.738   0.983    -4.374     0    5
#
#    speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# ...

# %%
# DISAPLY LAST FEW ROWS IN THE DATASET

data.tail()
# Out:
#                 track_name artist_name  artist_pop  \
# 218   Skinny Legend Anthem  Ava Louise          32
# 219          Material Girl     Madonna          77
# 220    I Wish - Radio Edit     Skee-Lo          51
# 221  Oh No I Got a Disease   Buss Crew          11
# 222                  Woahh        Jufu          31
#
#                                  album  track_pop  danceability  energy  \
# 218               Skinny Legend Anthem         50         0.845   0.518
# 219  Celebration (double disc version)         78         0.742   0.883
# 220                             I Wish         63         0.715   0.738
# 221              Oh No I Got a Disease         26         0.649   0.735
# 222                              Woahh         22         0.749   0.283
#
#      loudness  mode  key  speechiness  acousticness  instrumentalness  \
# 218    -7.568     1   11       0.2990       0.07030          0.000000
# 219    -3.419     1    0       0.0329       0.33300          0.000008
# ...

# %% [markdown]
# 𝑷𝑹𝑬𝑷𝑨𝑹𝑰𝑵𝑮 𝑻𝑯𝑬 𝑫𝑨𝑻𝑨𝑺𝑬𝑻

# %%
# DESCRIBE THE SHAPE - NUMBER OF ROWS AND COLUMNS

data.shape
# Out:
# (223, 18)

# %%
# INFORMATION REGARDING THE DATASET

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 223 entries, 0 to 222
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   track_name        223 non-null    object
#  1   artist_name       223 non-null    object
#  2   artist_pop        223 non-null    int64
#  3   album             223 non-null    object
#  4   track_pop         223 non-null    int64
#  5   danceability      223 non-null    float64
#  6   energy            223 non-null    float64
#  7   loudness          223 non-null    float64
#  8   mode              223 non-null    int64
#  9   key               223 non-null    int64
#  10  speechiness       223 non-null    float64
#  11  acousticness      223 non-null    float64
#  12  instrumentalness  223 non-null    float64
#  13  liveness          223 non-null    float64
#  14  valence           223 non-null    float64
#  15  tempo             223 non-null    float64
# ...

# %%
# DESCRIBING ALL THE COLUMNS PRESENT IN THE DATA

data.columns.values
# Out:
# array(['track_name', 'artist_name', 'artist_pop', 'album', 'track_pop',
#        'danceability', 'energy', 'loudness', 'mode', 'key', 'speechiness',
#        'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
#        'time_signature', 'duration_ms'], dtype=object)

# %%
# PRESENTING THE DATA IN MORE DETAILED WAY

for i in data.columns:
    print(i, end=", ")
# Out:
# track_name, artist_name, artist_pop, album, track_pop, danceability, energy, loudness, mode, key, speechiness, acousticness, instrumentalness, liveness, valence, tempo, time_signature, duration_ms,

# %% [markdown]
# 𝑼𝑵𝑫𝑬𝑹𝑺𝑻𝑨𝑵𝑫𝑰𝑵𝑮 𝑻𝑯𝑬 𝑫𝑨𝑻𝑨𝑺𝑬𝑻

# %%
# DISPLAY THE SUMMARY

data.describe()
# Out:
#        artist_pop   track_pop  danceability      energy    loudness  \
# count  223.000000  223.000000    223.000000  223.000000  223.000000
# mean    58.946188   50.192825      0.742673    0.607139   -7.381161
# std     18.124862   25.744474      0.140774    0.172197    3.134507
# min      0.000000    0.000000      0.247000    0.127000  -19.238000
# 25%     46.500000   42.500000      0.672000    0.475000   -8.799000
# 50%     61.000000   58.000000      0.749000    0.603000   -6.735000
# 75%     72.000000   69.000000      0.859000    0.736000   -5.114000
# max     93.000000   90.000000      0.978000    0.983000   -2.180000
#
#              mode         key  speechiness  acousticness  instrumentalness  \
# count  223.000000  223.000000   223.000000    223.000000        223.000000
# mean     0.650224    5.331839     0.149785      0.250346          0.033455
# std      0.477972    3.568786     0.141498      0.269444          0.137376
# ...

# %%
# FINDING UNIQUE VALUES IN TRACK NAME

data.track_name.unique()
# Out:
# array(['Shake It', 'Chinese New Year', "Baby I'm Yours", 'The Git Up',
#        'Say Hey (I Love You)', 'Falling for U', 'Shooting Stars', 'fast',
#        'On A Roll', 'Good Girls Bad Guys', 'Just Did a Bad Thing',
#        'Wait a Minute!', 'Spooky, Scary Skeletons',
#        "Livin' in the Sunlight, Lovin' in the Moon Light",
#        "Tell Me Something I Don't Know - Soundtrack",
#        'STUPID (feat. Yung Baby Tate)', 'Beef FloMix', 'Prom Queen',
#        "Don't Lose Ur Head", 'Legs (From "RuPaul\'s Drag Race 8")',
#        'Woah (feat. D3Mstreet)', "Steppin'", 'Hungry Hippo', "I'm Sorry",
#        "Vibin'", 'Fly Me To The Moon (In Other Words)', 'Yellow Hearts',
#        'Old Town Road', "I Don't Mind (feat. Juicy J)", 'ROXANNE',
#        'American Boy', 'Beggin (original version)',
#        'Put Your Head on My Shoulder', 'prom dress', 'Criminal', 'Runway',
#        "It's The Hard-Knock Life", 'Faucet Failure', 'Buttercup',
# ...

# %%
# FINDING UNIQUE VALUES IN ARTIST NAME

data.artist_name.unique()
# Out:
# array(['Metro Station', 'SALES', 'Breakbot', 'Blanco Brown',
#        'Michael Franti & Spearhead', 'Peachy!', 'Bag Raiders', 'Sueco',
#        'Ashley O', 'Falling In Reverse', 'Bill Wurtz', 'WILLOW',
#        'Andrew Gold', 'Tiny Tim', 'Selena Gomez', 'Ashnikko', 'Flo Milli',
#        'Beach Bunny', 'SIX', 'Lucian Piane', 'KRYPTO9095',
#        'Supa Dupa Humble', 'Tierra Whack', 'Swell', 'Kesh Kesh',
#        'Frank Sinatra', 'Ant Saunders', 'Lil Nas X', 'Usher',
#        'Arizona Zervas', 'Estelle', 'Madcon', 'Paul Anka', 'mxmtoon',
#        'Britney Spears', 'Stunna Girl', 'QuvenzhanÃ© Wallis',
#        'Ski Mask The Slump God', 'Jack Stauber', 'KYLE', 'Ambjaay',
#        'ilyTOMMY', 'Tiny Meat Gang', 'iLOVEFRiDAY', 'Riton', 'Little Mix',
#        'ZaeHD & CEO', 'Y2K', 'Valee', 'Toby Fox', 'DJ Scheme',
#        'Louie Zong', 'Lizzo', 'tobi lou', 'Lonely God', 'Savage Ga$p',
#        'Absofacto', 'Kero Kero Bonito', 'Jufu', 'Verzache', 'PUBLIC',
# ...

# %% [markdown]
# 𝑨𝑻𝑻𝑹𝑰𝑩𝑼𝑻𝑬𝑺 𝑶𝑭 𝑻𝑯𝑬 𝑫𝑨𝑻𝑨𝑺𝑬𝑻

# %%
# DATA TYPES OF EACH COLUMN

data.dtypes
# Out:
# track_name           object
# artist_name          object
# artist_pop            int64
# album                object
# track_pop             int64
# danceability        float64
# energy              float64
# loudness            float64
# mode                  int64
# key                   int64
# speechiness         float64
# acousticness        float64
# instrumentalness    float64
# liveness            float64
# valence             float64
# tempo               float64
# time_signature        int64
# duration_ms           int64
# dtype: object

# %%
# DISTRIBUTION OF ATTRIBUTES

# GIVES THE ANALYSIS FOR OBJECT TYPE IN THE DATASET

data.describe(include=['object'])
# Out:
#        track_name artist_name                                     album
# count         223         223                                       223
# unique        221         209                                       220
# top       Falling         SIX  Six: The Musical (Studio Cast Recording)
# freq            2           3                                         3

# %%
# DISTRIBUTION OF ATTRIBUTES

# GIVES THE ANALYSIS FOR INT TYPE IN THE DATASET

data.describe(include=['int'])
# Out:
#        artist_pop   track_pop        mode         key  time_signature  \
# count  223.000000  223.000000  223.000000  223.000000      223.000000
# mean    58.946188   50.192825    0.650224    5.331839        3.977578
# std     18.124862   25.744474    0.477972    3.568786        0.275811
# min      0.000000    0.000000    0.000000    0.000000        1.000000
# 25%     46.500000   42.500000    0.000000    2.000000        4.000000
# 50%     61.000000   58.000000    1.000000    5.000000        4.000000
# 75%     72.000000   69.000000    1.000000    8.000000        4.000000
# max     93.000000   90.000000    1.000000   11.000000        5.000000
#
#          duration_ms
# count     223.000000
# mean   180451.502242
# std     54352.579901
# min     43427.000000
# 25%    145440.000000
# 50%    177479.000000
# 75%    216779.500000
# max    410089.000000

# %%
# DISTRIBUTION OF ATTRIBUTES

# GIVES THE ANALYSIS FOR FLOAT TYPE IN THE DATASET

data.describe(exclude=['object','int'])
# Out:
#        danceability      energy    loudness  speechiness  acousticness  \
# count    223.000000  223.000000  223.000000   223.000000    223.000000
# mean       0.742673    0.607139   -7.381161     0.149785      0.250346
# std        0.140774    0.172197    3.134507     0.141498      0.269444
# min        0.247000    0.127000  -19.238000     0.026100      0.000122
# 25%        0.672000    0.475000   -8.799000     0.044550      0.030600
# 50%        0.749000    0.603000   -6.735000     0.087400      0.140000
# 75%        0.859000    0.736000   -5.114000     0.222000      0.391500
# max        0.978000    0.983000   -2.180000     0.730000      0.984000
#
#        instrumentalness    liveness     valence       tempo
# count        223.000000  223.000000  223.000000  223.000000
# mean           0.033455    0.166932    0.582637  122.196578
# std            0.137376    0.131863    0.218522   27.201311
# min            0.000000    0.019400    0.070000   62.619000
# ...

# %% [markdown]
# 𝑪𝑯𝑬𝑪𝑲𝑰𝑵𝑮 𝑭𝑶𝑹 𝑴𝑰𝑺𝑺𝑰𝑵𝑮 𝑽𝑨𝑳𝑼𝑬𝑺

# %%
# CHECKING FOR NULL VALUES

data.isnull().sum()
# Out:
# track_name          0
# artist_name         0
# artist_pop          0
# album               0
# track_pop           0
# danceability        0
# energy              0
# loudness            0
# mode                0
# key                 0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# time_signature      0
# duration_ms         0
# dtype: int64

# %% [markdown]
# 𝑪𝑶𝑹𝑹𝑬𝑳𝑨𝑻𝑰𝑶𝑵𝑺 𝑩𝑬𝑻𝑾𝑬𝑬𝑵 𝑻𝑯𝑬 𝑨𝑻𝑻𝑹𝑰𝑩𝑼𝑻𝑬𝑺

# %%
# CHECK FOR CORRELATION BETWEEN NUMERICAL ATTRIBUTES

data.corr()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_11156\850750819.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corr()
#                   artist_pop  track_pop  danceability    energy  loudness  \
# artist_pop          1.000000   0.371656     -0.130318  0.149147  0.306415
# track_pop           0.371656   1.000000     -0.128331  0.111767  0.228435
# danceability       -0.130318  -0.128331      1.000000 -0.073789  0.027604
# energy              0.149147   0.111767     -0.073789  1.000000  0.681296
# loudness            0.306415   0.228435      0.027604  0.681296  1.000000
# mode               -0.084856   0.028202     -0.032370 -0.113298 -0.128377
# key                 0.037813  -0.066201     -0.072175 -0.040515 -0.055901
# speechiness        -0.358864  -0.203603      0.368436 -0.116993 -0.079823
# ...

# %%
correlation_1 = data.corr()

plt.figure(figsize = (25,25))
sns.heatmap(correlation_1, annot = True, linewidth=.4, cmap="PiYG")
plt.title("TIKTOK POPULAR SONGS", fontsize = 50, color="Black")
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_11156\2209014426.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_1 = data.corr()
